# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python312\Lib\site-packages)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="378e1b98dc9c494097a5aa43c09ec247", client_secret="457b85ab00fa42a4aee88bfe7c9209a0")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Worldwide Chart Hits – Global Pop & Rap Anthems 2025
playlist_link = "https://open.spotify.com/playlist/4zzUm9eZmeb4t4nUCaNoo5"

# %%
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '4zzUm9eZmeb4t4nUCaNoo5'

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '1eCGY9WJpYgtaFh1Lk2KNo'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-09-26'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 11

# %%
data['items'][0]['track']['album']['id']
# Out:
# '1eCGY9WJpYgtaFh1Lk2KNo'

# %%
data['items'][0]['track']['album']['name']
# Out:
# "You'll Be Alright, Kid (Chapter 1)"

# %%
data['items'][0]['track']['album']['artists'][0]['name']
# Out:
# 'Alex Warren'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_link=row['track']['album']['external_urls']['spotify']
    album_name=row['track']['album']['name']
    album_element={'album_id':album_id,'release_date':album_release_date,'total_tracks':album_total_tracks,'link':album_link,'name':album_name}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '1eCGY9WJpYgtaFh1Lk2KNo',
#   'release_date': '2024-09-26',
#   'total_tracks': 11,
#   'link': 'https://open.spotify.com/album/1eCGY9WJpYgtaFh1Lk2KNo',
#   'name': "You'll Be Alright, Kid (Chapter 1)"},
#  {'album_id': '3DmDoHxAeEiDFNWrHSKAdQ',
#   'release_date': '2025-05-16',
#   'total_tracks': 7,
#   'link': 'https://open.spotify.com/album/3DmDoHxAeEiDFNWrHSKAdQ',
#   'name': 'Echo'},
#  {'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'release_date': '2025-03-07',
#   'total_tracks': 14,
#   'link': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ',
#   'name': 'MAYHEM'},
#  {'album_id': '7I21t27Gd8tqFB1ap1s26A',
#   'release_date': '2025-05-02',
#   'total_tracks': 1,
#   'link': 'https://open.spotify.com/album/7I21t27Gd8tqFB1ap1s26A',
#   'name': 'Drunk On Love'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'link': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n',
# ...

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'external_url': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '5vV3bFXnN6D6N3Nj4xRvaV',
#   'artist_name': 'Jin',
#   'external_url': 'https://api.spotify.com/v1/artists/5vV3bFXnN6D6N3Nj4xRvaV'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '3sSkr4TQRtXMDOkjEQxHvb',
#   'artist_name': 'Lucas Tillian',
#   'external_url': 'https://api.spotify.com/v1/artists/3sSkr4TQRtXMDOkjEQxHvb'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '2nl7s3ZFvCqP7yZmoh9vwA',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
song_list=[]
for row in data['items']:
    song_id=row['track']['id']
    song_name=row['track']['name']
    song_duration=row['track']['duration_ms']
    song_url=row['track']['external_urls']['spotify']
    song_popularity=row['track']['popularity']
    song_added=row['added_at']
    album_id=row['track']['album']['id']
    artist_id=row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id release_date  total_tracks  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo   2024-09-26            11
# 1  3DmDoHxAeEiDFNWrHSKAdQ   2025-05-16             7
# 2  2MHUaRi9OCyTN02SoyRRBJ   2025-03-07            14
# 3  7I21t27Gd8tqFB1ap1s26A   2025-05-02             1
# 4  7aJuG4TFXa2hmE4z1yxc3n   2024-05-17            10
#
#                                                 link  \
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/3DmDoHxAeEiDFNW...
# 2  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 3  https://open.spotify.com/album/7I21t27Gd8tqFB1...
# 4  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
#
#                                  name
# 0  You'll Be Alright, Kid (Chapter 1)
# 1                                Echo
# 2                              MAYHEM
# 3                       Drunk On Love
# 4                HIT ME HARD AND SOFT

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   release_date  100 non-null    object
#  2   total_tracks  100 non-null    int64
#  3   link          100 non-null    object
#  4   name          100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      95 non-null     object
#  1   release_date  95 non-null     object
#  2   total_tracks  95 non-null     int64
#  3   link          95 non-null     object
#  4   name          95 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.5+ KB

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB    Alex Warren
# 1  5vV3bFXnN6D6N3Nj4xRvaV            Jin
# 2  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 3  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 4  3sSkr4TQRtXMDOkjEQxHvb  Lucas Tillian
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1  https://api.spotify.com/v1/artists/5vV3bFXnN6D...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/3sSkr4TQRtX...

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df=pd.DataFrame.from_dict(song_list)

# %%
album_df.head()
# Out:
#                  album_id release_date  total_tracks  \
# 0  1eCGY9WJpYgtaFh1Lk2KNo   2024-09-26            11
# 1  3DmDoHxAeEiDFNWrHSKAdQ   2025-05-16             7
# 2  2MHUaRi9OCyTN02SoyRRBJ   2025-03-07            14
# 3  7I21t27Gd8tqFB1ap1s26A   2025-05-02             1
# 4  7aJuG4TFXa2hmE4z1yxc3n   2024-05-17            10
#
#                                                 link  \
# 0  https://open.spotify.com/album/1eCGY9WJpYgtaFh...
# 1  https://open.spotify.com/album/3DmDoHxAeEiDFNW...
# 2  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 3  https://open.spotify.com/album/7I21t27Gd8tqFB1...
# 4  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
#
#                                  name
# 0  You'll Be Alright, Kid (Chapter 1)
# 1                                Echo
# 2                              MAYHEM
# 3                       Drunk On Love
# 4                HIT ME HARD AND SOFT

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB    Alex Warren
# 1  5vV3bFXnN6D6N3Nj4xRvaV            Jin
# 2  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 3  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 4  3sSkr4TQRtXMDOkjEQxHvb  Lucas Tillian
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1  https://api.spotify.com/v1/artists/5vV3bFXnN6D...
# 2  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 3  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 4  https://api.spotify.com/v1/artists/3sSkr4TQRtX...

# %%
song_df.head()
# Out:
#                   song_id              song_name  duration_ms  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ               Ordinary       186964
# 1  27xkOIER6uDLKALIelHylZ  Don’t Say You Love Me       180716
# 2  7so0lgd0zP2Sbgs2d7a1SZ       Die With A Smile       251667
# 3  7gtBB54UUt18trgwfLBDGt          Drunk On Love       190000
# 4  6dOtVTDdiauQNBQEDOtlAB     BIRDS OF A FEATHER       210373
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2RkZ5LkEzeHGRsm...          94
# 1  https://open.spotify.com/track/27xkOIER6uDLKAL...          91
# 2  https://open.spotify.com/track/7so0lgd0zP2Sbgs...          91
# 3  https://open.spotify.com/track/7gtBB54UUt18trg...          27
# 4  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         100
#
#              song_added                album_id               artist_id
# 0  2025-05-15T13:51:39Z  1eCGY9WJpYgtaFh1Lk2KNo  0fTSzq9jAh4c36UVb4V7CB
# ...

# %%
album_df['release_date']=pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      94 non-null     object
#  1   release_date  94 non-null     datetime64[ns]
#  2   total_tracks  94 non-null     int64
#  3   link          94 non-null     object
#  4   name          94 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 6.5+ KB

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id              song_name  duration_ms  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ               Ordinary       186964
# 1  27xkOIER6uDLKALIelHylZ  Don’t Say You Love Me       180716
# 2  7so0lgd0zP2Sbgs2d7a1SZ       Die With A Smile       251667
# 3  7gtBB54UUt18trgwfLBDGt          Drunk On Love       190000
# 4  6dOtVTDdiauQNBQEDOtlAB     BIRDS OF A FEATHER       210373
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2RkZ5LkEzeHGRsm...          94
# 1  https://open.spotify.com/track/27xkOIER6uDLKAL...          91
# 2  https://open.spotify.com/track/7so0lgd0zP2Sbgs...          91
# 3  https://open.spotify.com/track/7gtBB54UUt18trg...          27
# 4  https://open.spotify.com/track/6dOtVTDdiauQNBQ...         100
#
#                  song_added                album_id               artist_id
# 0 2025-05-15 13:51:39+00:00  1eCGY9WJpYgtaFh1Lk2KNo  0fTSzq9jAh4c36UVb4V7CB
# ...
